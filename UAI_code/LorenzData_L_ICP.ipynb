# %% [markdown]
# ### This code creates the results used in Section 6.3

# %%
### Some initializations
import numpy as np
import random
import loli
import pickle
from scipy.stats import binomtest

# %%
# The function that generates the dynamical data

def lordata_gen(size):
    X=np.zeros((size+1,6))
    X[0,:]=[2,0.97,0.99,1,0.97,1]
    
    
    for t in range(size):
        e=np.random.multivariate_normal(np.zeros(6),np.eye(6))
        x_new=[X[t,0]*0.9+0.1*X[t,1]+e[0],\
               0.28*X[t,0]-0.01*X[t,0]*X[t,2]+0.99*X[t,1]+e[1],\
               0.01*X[t,0]*X[t,1]-0.01*X[t,0]*X[t,3]+0.9733*X[t,2]+e[2],\
               0.01*X[t,0]*X[t,2]-0.02*X[t,0]*X[t,4]+0.9366*X[t,3]+e[3],\
               0.02*X[t,0]*X[t,3]+0.96*X[t,4]+e[4],
                  X[t,5]+e[5]]
        X[t+1,:]=x_new

    return(X)

# %%
# Running our algorithm on the Lorenz data

rs=1
np.random.seed(rs)
size=8500 # The size of the generated dataset
E=300 # The number of environments
runs=500 # How often we repeat the experiment 
results={}
for n in [20,25]:  # n is the sample size (length of the interval)
    for tar in range(6):
        results[tar]={}
    for j in range(runs):
        print('Run',j,'out of',runs)
        X=lordata_gen(size)
        dataX=[X[499+i*n:499+(i+1)*n,:] for i in range(E)]
        for tar in range(6):
            dataY=[X[499+i*n+1:499+(i+1)*n+1,tar] for i in range(E)]
            plausibleS=loli.gauss(dataX,dataY,alpha=0.1,B=500)
            if len(plausibleS)==0:
                supphat=set()
            else:
                supphat=set.intersection(*plausibleS)
            if tuple(supphat) in results[tar]:
                results[tar][tuple(supphat)]+=1
            else:
                results[tar][tuple(supphat)]=1

    with open('LorenzGenResultsE='+str(E)+'N='+str(n)+'.pkl','wb') as f:
        pickle.dump(results, f)
# Out:
# Run 453 out of 500
# Run 454 out of 500
# Run 455 out of 500
# Run 456 out of 500
# Run 457 out of 500
# Run 458 out of 500
# Run 459 out of 500
# Run 460 out of 500
# Run 461 out of 500
# Run 462 out of 500
# Run 463 out of 500
# Run 464 out of 500
# Run 465 out of 500
# Run 466 out of 500
# Run 467 out of 500
# Run 468 out of 500
# Run 469 out of 500
# Run 470 out of 500
# Run 471 out of 500
# Run 472 out of 500
# Run 473 out of 500
# Run 474 out of 500
# Run 475 out of 500
# Run 476 out of 500
# Run 477 out of 500
# Run 478 out of 500
# Run 479 out of 500
# Run 480 out of 500
# Run 481 out of 500
# Run 482 out of 500
# Run 483 out of 500
# Run 484 out of 500
# Run 485 out of 500
# Run 486 out of 500
# Run 487 out of 500
# Run 488 out of 500
# Run 489 out of 500
# Run 490 out of 500
# Run 491 out of 500
# Run 492 out of 500
# Run 493 out of 500
# Run 494 out of 500
# Run 495 out of 500
# Run 496 out of 500
# Run 497 out of 500
# Run 498 out of 500
# Run 499 out of 500
# Run 0 out of 500
# Run 1 out of 500
# Run 2 out of 500
# Run 3 out of 500
# Run 4 out of 500
# Run 5 out of 500
# Run 6 out of 500
# Run 7 out of 500
# Run 8 out of 500
# Run 9 out of 500
# Run 10 out of 500
# Run 11 out of 500
# Run 12 out of 500
# Run 13 out of 500
# Run 14 out of 500
# Run 15 out of 500
# Run 16 out of 500
# Run 17 out of 500
# Run 18 out of 500
# Run 19 out of 500
# Run 20 out of 500
# Run 21 out of 500
# Run 22 out of 500
# Run 23 out of 500
# Run 24 out of 500
# Run 25 out of 500
# Run 26 out of 500
# Run 27 out of 500
# Run 28 out of 500
# Run 29 out of 500
# Run 30 out of 500
# Run 31 out of 500
# Run 32 out of 500
# Run 33 out of 500
# Run 34 out of 500
# Run 35 out of 500
# Run 36 out of 500
# Run 37 out of 500
# Run 38 out of 500
# Run 39 out of 500
# Run 40 out of 500
# Run 41 out of 500
# Run 42 out of 500
# Run 43 out of 500
# Run 44 out of 500
# Run 45 out of 500
# Run 46 out of 500
# Run 47 out of 500
# Run 48 out of 500
# Run 49 out of 500
# Run 50 out of 500
# Run 51 out of 500
# Run 52 out of 500
# Run 53 out of 500
# Run 54 out of 500
# Run 55 out of 500
# Run 56 out of 500
# Run 57 out of 500
# Run 58 out of 500
# Run 59 out of 500
# Run 60 out of 500
# Run 61 out of 500
# Run 62 out of 500
# Run 63 out of 500
# Run 64 out of 500
# Run 65 out of 500
# Run 66 out of 500
# Run 67 out of 500
# Run 68 out of 500
# Run 69 out of 500
# Run 70 out of 500
# Run 71 out of 500
# Run 72 out of 500
# Run 73 out of 500
# Run 74 out of 500
# Run 75 out of 500
# Run 76 out of 500
# Run 77 out of 500
# Run 78 out of 500
# Run 79 out of 500
# Run 80 out of 500
# Run 81 out of 500
# Run 82 out of 500
# Run 83 out of 500
# Run 84 out of 500
# Run 85 out of 500
# Run 86 out of 500
# Run 87 out of 500
# Run 88 out of 500
# Run 89 out of 500
# Run 90 out of 500
# Run 91 out of 500
# Run 92 out of 500
# Run 93 out of 500
# Run 94 out of 500
# Run 95 out of 500
# Run 96 out of 500
# Run 97 out of 500
# Run 98 out of 500
# Run 99 out of 500
# Run 100 out of 500
# Run 101 out of 500
# Run 102 out of 500
# Run 103 out of 500
# Run 104 out of 500
# Run 105 out of 500
# Run 106 out of 500
# Run 107 out of 500
# Run 108 out of 500
# Run 109 out of 500
# Run 110 out of 500
# Run 111 out of 500
# Run 112 out of 500
# Run 113 out of 500
# Run 114 out of 500
# Run 115 out of 500
# Run 116 out of 500
# Run 117 out of 500
# Run 118 out of 500
# Run 119 out of 500
# Run 120 out of 500
# Run 121 out of 500
# Run 122 out of 500
# Run 123 out of 500
# Run 124 out of 500
# Run 125 out of 500
# Run 126 out of 500
# Run 127 out of 500
# Run 128 out of 500
# Run 129 out of 500
# Run 130 out of 500
# Run 131 out of 500
# Run 132 out of 500
# Run 133 out of 500
# Run 134 out of 500
# Run 135 out of 500
# Run 136 out of 500
# Run 137 out of 500
# Run 138 out of 500
# Run 139 out of 500
# Run 140 out of 500
# Run 141 out of 500
# Run 142 out of 500
# Run 143 out of 500
# Run 144 out of 500
# Run 145 out of 500
# Run 146 out of 500
# Run 147 out of 500
# Run 148 out of 500
# Run 149 out of 500
# Run 150 out of 500
# Run 151 out of 500
# Run 152 out of 500
# Run 153 out of 500
# Run 154 out of 500
# Run 155 out of 500
# Run 156 out of 500
# Run 157 out of 500
# Run 158 out of 500
# Run 159 out of 500
# Run 160 out of 500
# Run 161 out of 500
# Run 162 out of 500
# Run 163 out of 500
# Run 164 out of 500
# Run 165 out of 500
# Run 166 out of 500
# Run 167 out of 500
# Run 168 out of 500
# Run 169 out of 500
# Run 170 out of 500
# Run 171 out of 500
# Run 172 out of 500
# Run 173 out of 500
# Run 174 out of 500
# Run 175 out of 500
# Run 176 out of 500
# Run 177 out of 500
# Run 178 out of 500
# Run 179 out of 500
# Run 180 out of 500
# Run 181 out of 500
# Run 182 out of 500
# Run 183 out of 500
# Run 184 out of 500
# Run 185 out of 500
# Run 186 out of 500
# Run 187 out of 500
# Run 188 out of 500
# Run 189 out of 500
# Run 190 out of 500
# Run 191 out of 500
# Run 192 out of 500
# Run 193 out of 500
# Run 194 out of 500
# Run 195 out of 500
# Run 196 out of 500
# Run 197 out of 500
# Run 198 out of 500
# Run 199 out of 500
# Run 200 out of 500
# Run 201 out of 500
# Run 202 out of 500
# Run 203 out of 500
# Run 204 out of 500
# Run 205 out of 500
# Run 206 out of 500
# Run 207 out of 500
# Run 208 out of 500
# Run 209 out of 500
# Run 210 out of 500
# Run 211 out of 500
# Run 212 out of 500
# Run 213 out of 500
# Run 214 out of 500
# Run 215 out of 500
# Run 216 out of 500
# Run 217 out of 500
# Run 218 out of 500
# Run 219 out of 500
# Run 220 out of 500
# Run 221 out of 500
# Run 222 out of 500
# Run 223 out of 500
# Run 224 out of 500
# Run 225 out of 500
# Run 226 out of 500
# Run 227 out of 500
# Run 228 out of 500
# Run 229 out of 500
# Run 230 out of 500
# Run 231 out of 500
# Run 232 out of 500
# Run 233 out of 500
# Run 234 out of 500
# Run 235 out of 500
# Run 236 out of 500
# Run 237 out of 500
# Run 238 out of 500
# Run 239 out of 500
# Run 240 out of 500
# Run 241 out of 500
# Run 242 out of 500
# Run 243 out of 500
# Run 244 out of 500
# Run 245 out of 500
# Run 246 out of 500
# Run 247 out of 500
# Run 248 out of 500
# Run 249 out of 500
# Run 250 out of 500
# Run 251 out of 500
# Run 252 out of 500
# Run 253 out of 500
# Run 254 out of 500
# Run 255 out of 500
# Run 256 out of 500
# Run 257 out of 500
# Run 258 out of 500
# Run 259 out of 500
# Run 260 out of 500
# Run 261 out of 500
# Run 262 out of 500
# Run 263 out of 500
# Run 264 out of 500
# Run 265 out of 500
# Run 266 out of 500
# Run 267 out of 500
# Run 268 out of 500
# Run 269 out of 500
# Run 270 out of 500
# Run 271 out of 500
# Run 272 out of 500
# Run 273 out of 500
# Run 274 out of 500
# Run 275 out of 500
# Run 276 out of 500
# Run 277 out of 500
# Run 278 out of 500
# Run 279 out of 500
# Run 280 out of 500
# Run 281 out of 500
# Run 282 out of 500
# Run 283 out of 500
# Run 284 out of 500
# Run 285 out of 500
# Run 286 out of 500
# Run 287 out of 500
# Run 288 out of 500
# Run 289 out of 500
# Run 290 out of 500
# Run 291 out of 500
# Run 292 out of 500
# Run 293 out of 500
# Run 294 out of 500
# Run 295 out of 500
# Run 296 out of 500
# Run 297 out of 500
# Run 298 out of 500
# Run 299 out of 500
# Run 300 out of 500
# Run 301 out of 500
# Run 302 out of 500
# Run 303 out of 500
# Run 304 out of 500
# Run 305 out of 500
# Run 306 out of 500
# Run 307 out of 500
# Run 308 out of 500
# Run 309 out of 500
# Run 310 out of 500
# Run 311 out of 500
# Run 312 out of 500
# Run 313 out of 500
# Run 314 out of 500
# Run 315 out of 500
# Run 316 out of 500
# Run 317 out of 500
# Run 318 out of 500
# Run 319 out of 500
# Run 320 out of 500
# Run 321 out of 500
# Run 322 out of 500
# Run 323 out of 500
# Run 324 out of 500
# Run 325 out of 500
# Run 326 out of 500
# Run 327 out of 500
# Run 328 out of 500
# Run 329 out of 500
# Run 330 out of 500
# Run 331 out of 500
# Run 332 out of 500
# Run 333 out of 500
# Run 334 out of 500
# Run 335 out of 500
# Run 336 out of 500
# Run 337 out of 500
# Run 338 out of 500
# Run 339 out of 500
# Run 340 out of 500
# Run 341 out of 500
# Run 342 out of 500
# Run 343 out of 500
# Run 344 out of 500
# Run 345 out of 500
# Run 346 out of 500
# Run 347 out of 500
# Run 348 out of 500
# Run 349 out of 500
# Run 350 out of 500
# Run 351 out of 500
# Run 352 out of 500
# Run 353 out of 500
# Run 354 out of 500
# Run 355 out of 500
# Run 356 out of 500
# Run 357 out of 500
# Run 358 out of 500
# Run 359 out of 500
# Run 360 out of 500
# Run 361 out of 500
# Run 362 out of 500
# Run 363 out of 500
# Run 364 out of 500
# Run 365 out of 500
# Run 366 out of 500
# Run 367 out of 500
# Run 368 out of 500
# Run 369 out of 500
# Run 370 out of 500
# Run 371 out of 500
# Run 372 out of 500
# Run 373 out of 500
# Run 374 out of 500
# Run 375 out of 500
# Run 376 out of 500
# Run 377 out of 500
# Run 378 out of 500
# Run 379 out of 500
# Run 380 out of 500
# Run 381 out of 500
# Run 382 out of 500
# Run 383 out of 500
# Run 384 out of 500
# Run 385 out of 500
# Run 386 out of 500
# Run 387 out of 500
# Run 388 out of 500
# Run 389 out of 500
# Run 390 out of 500
# Run 391 out of 500
# Run 392 out of 500
# Run 393 out of 500
# Run 394 out of 500
# Run 395 out of 500
# Run 396 out of 500
# Run 397 out of 500
# Run 398 out of 500
# Run 399 out of 500
# Run 400 out of 500
# Run 401 out of 500
# Run 402 out of 500
# Run 403 out of 500
# Run 404 out of 500
# Run 405 out of 500
# Run 406 out of 500
# Run 407 out of 500
# Run 408 out of 500
# Run 409 out of 500
# Run 410 out of 500
# Run 411 out of 500
# Run 412 out of 500
# Run 413 out of 500
# Run 414 out of 500
# Run 415 out of 500
# Run 416 out of 500
# Run 417 out of 500
# Run 418 out of 500
# Run 419 out of 500
# Run 420 out of 500
# Run 421 out of 500
# Run 422 out of 500
# Run 423 out of 500
# Run 424 out of 500
# Run 425 out of 500
# Run 426 out of 500
# Run 427 out of 500
# Run 428 out of 500
# Run 429 out of 500
# Run 430 out of 500
# Run 431 out of 500
# Run 432 out of 500
# Run 433 out of 500
# Run 434 out of 500
# Run 435 out of 500
# Run 436 out of 500
# Run 437 out of 500
# Run 438 out of 500
# Run 439 out of 500
# Run 440 out of 500
# Run 441 out of 500
# Run 442 out of 500
# Run 443 out of 500
# Run 444 out of 500
# Run 445 out of 500
# Run 446 out of 500
# Run 447 out of 500
# Run 448 out of 500
# Run 449 out of 500
# Run 450 out of 500
# Run 451 out of 500
# Run 452 out of 500
# Run 453 out of 500
# Run 454 out of 500
# Run 455 out of 500
# Run 456 out of 500
# Run 457 out of 500
# Run 458 out of 500
# Run 459 out of 500
# Run 460 out of 500
# Run 461 out of 500
# Run 462 out of 500
# Run 463 out of 500
# Run 464 out of 500
# Run 465 out of 500
# Run 466 out of 500
# Run 467 out of 500
# Run 468 out of 500
# Run 469 out of 500
# Run 470 out of 500
# Run 471 out of 500
# Run 472 out of 500
# Run 473 out of 500
# Run 474 out of 500
# Run 475 out of 500
# Run 476 out of 500
# Run 477 out of 500
# Run 478 out of 500
# Run 479 out of 500
# Run 480 out of 500
# Run 481 out of 500
# Run 482 out of 500
# Run 483 out of 500
# Run 484 out of 500
# Run 485 out of 500
# Run 486 out of 500
# Run 487 out of 500
# Run 488 out of 500
# Run 489 out of 500
# Run 490 out of 500
# Run 491 out of 500
# Run 492 out of 500
# Run 493 out of 500
# Run 494 out of 500
# Run 495 out of 500
# Run 496 out of 500
# Run 497 out of 500
# Run 498 out of 500
# Run 499 out of 500
# Run 0 out of 500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#      16 for tar in range(6):
#      17     dataY=[X[499+i*n+1:499+(i+1)*n+1,tar] for i in range(E)]
# ---> 18     plausibleS=loli.gauss(dataX,dataY,alpha=0.1,B=500)
#      19     if len(plausibleS)==0:
#      20         supphat=set()
#
# File ~\OneDrive - TU Eindhoven\Documents\Github\causal-local-linear\MainAlgo\loli.py:31, in gauss(x, y, B, l, alpha, lam, rs, intercept, pvalues)
#      29 m=len(ind)+intercept
#      30 if (n,0) not in Simulations:
# ---> 31     Simulations[(i,n,intercept+d)]=(np.random.chisquare(n-d-1,B))
#      32     for q in range(1,intercept+d):
#      33         Simulations[(i,n,intercept+d-q)]=Simulations[(i,n,intercept+d-q+1)]+(np.random.normal(size=(B)))**2
#
# File mtrand.pyx:1964, in numpy.random.mtrand.RandomState.chisquare()
#
# File _common.pyx:612, in numpy.random._common.cont()
#
# File _common.pyx:427, in numpy.random._common.check_constraint()
#
# ValueError: df <= 0

# %%
# Showing the results, different rows correspond to different targets and different columns to the potential causal parents

E=300
for n in [20,25]:
    with open('LorenzGenResultsE='+str(E)+'N='+str(n)+'.pkl','rb') as f:
        Lorenz=pickle.load(f)
    
    
    final=np.zeros((6,6))
    for tar in range(6):
        for key in Lorenz[tar]:
            for var in range(6):
                if var in key:
                    final[tar,var]+=Lorenz[tar][key]
    print('Raw counts for n=',n)
    print(final)
    pvals=np.zeros((6,6))
    for i in range(6):
        for j in range(6):
            test=binomtest(np.int32(final[i,j]),500,0.1,alternative='greater')
            pvals[i,j]=test.pvalue
    print('Maxtrix of causal parents for n=',n)
    print(pvals<0.05)

# %%
# Alternatively we can directly load the results from the saved file

E=300
for n in [20,25]:
    with open('SavedResults/LorenzData/LorenzGenResultsE='+str(E)+'N='+str(n)+'.pkl','rb') as f:
        Lorenz=pickle.load(f)
    
    
    final=np.zeros((6,6))
    for tar in range(6):
        for key in Lorenz[tar]:
            for var in range(6):
                if var in key:
                    final[tar,var]+=Lorenz[tar][key]
    print('Raw counts for n=',n)
    print(final)
    pvals=np.zeros((6,6))
    for i in range(6):
        for j in range(6):
            test=binomtest(np.int32(final[i,j]),500,0.1,alternative='greater')
            pvals[i,j]=test.pvalue
    print('Maxtrix of causal parents for n=',n)
    print(pvals<0.05)
