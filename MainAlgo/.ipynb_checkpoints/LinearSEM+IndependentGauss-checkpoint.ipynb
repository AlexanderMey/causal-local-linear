# %%
### In here we perform the initial simple tests. The covariates are all independent gaussian variables. We then plot the
### performance against the change of some crucial parameters

# %%
### Some initializations
import numpy as np
import math
import random
import copy
import matplotlib.pyplot as plt
import scipy
from matplotlib.patches import Patch
import scipy.stats
import warnings
import itertools
import loli
from heapq import nlargest
from sklearn.cluster import KMeans

# %%
mean
# Out:
# array([-0.2359007 ,  1.65355651, -1.82044448, -0.23582125, -0.82431705,
#        -1.56921788])

# %%
### Changing sample size
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
sample=[8,12,16,20,24,28]
fntrunc=np.zeros((len(sample)))
fptrunc=np.zeros((len(sample)))
fnt=np.zeros((len(sample)))
fpt=np.zeros((len(sample)))
fnind=np.zeros((len(sample)))
fpind=np.zeros((len(sample)))
fn=np.zeros((len(sample)))
fp=np.zeros((len(sample)))
runs=100
l=1 # Number of intervals we combine for the statistics
B=100 # Bootstrap runs
I=50      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,n in enumerate(sample):
    print('Sample size',o+1,'of',len(sample))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        Xtrunc=[]
        Ytrunc=[]
        Xt=[]
        Yt=[]
        for i in range(I):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=5,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),2*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            ytrunc=np.zeros((n))
            yt=np.zeros((n))
            xtrunc=np.zeros((n,d))
            xt=np.zeros((n,d))
            
            mean=np.random.uniform(low=-1,high=1,size=(d))
            for p in range(d):
                temp=np.random.normal(mean[p],scale=std[p],size=(n))
                ind=np.where(temp>1.5+mean[p])
                temp[ind]=1.5+mean[p]
                ind=np.where(e<-1.5+mean[p])
                temp[ind]=-1.5+mean[p]
                xtrunc[:,p]=temp
                xt[:,p]=np.random.standard_t(2*(std[p])**(1/2)/((std[p])**(1/2)-1),size=(n))+mean[p]
                xind[:,p]=np.random.normal(mean[p],scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            etrunc=np.random.multivariate_normal(0*np.ones(n),2*np.eye(n))
            ind=np.where(etrunc>2.5)
            etrunc[ind]=2.5
            ind=np.where(e<-2.5)
            etrunc[ind]=-2.5
            ytrunc=xtrunc@betas[r,i,:]+etrunc
            et=np.random.standard_t(2*(2)**(1/2)/((2)**(1/2)-1),size=(n))
            yt=xt@betas[r,i,:]+et
            
            Xind.append(xind)
            Yind.append(yind)
            Xtrunc.append(xtrunc)
            Ytrunc.append(ytrunc)
            Xt.append(xt)
            Yt.append(yt)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs
                
                
        plausibleS=loli.gauss(Xtrunc,Ytrunc)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fptrunc[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fntrunc[o]+=1/runs
                
        plausibleS=loli.gauss(Xt,Yt)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpt[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnt[o]+=1/runs

fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
    
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
sem = Patch([], [], color='#785EF0',label='SEM')
normal = Patch([], [], color='#DC267F',label='Normal')
trunc = Patch([], [], color='#FE6100',label='Truncated normal')
student = Patch([], [], color='#009E73',label='Student-t')
conf= plt.Line2D([], [], color='black',label='Confidence level')

plt.plot(sample,0.1*np.ones((len(sample))),label='Confidence level',color='black')
plt.plot(sample,fp,'#785EF0',label='False Positive SEM',linestyle=(0, (5, 1)))
plt.plot(sample,fpind,'#DC267F',label='False Positive Normal',linestyle=(0, (5, 1)))
plt.plot(sample,fn,'#785EF0',label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(sample,fnind,'#DC267F',label='False Negative Normal',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
ax.legend(handles=[false_pos,false_neg,conf,sem,normal])
plt.xticks(sample)
plt.xlabel('Sample Size per Environment',fontsize=14)
plt.ylabel('Rate',fontsize=14)
plt.show()
plt.savefig('Figures/SamplechangSem='+str(I)+'.eps',bbox_inches="tight",format='eps')


fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(sample,0.1*np.ones((len(sample))),label='Confidence level',color='black')
plt.plot(sample,fptrunc,'#FE6100',label='False Positive Truncated',linestyle=(0, (5, 1)))
plt.plot(sample,fpt,'#009E73',label='False Positive Student-t',linestyle=(0, (5, 1)))
plt.plot(sample,fntrunc,'#FE6100',label='False Negative Truncated',linestyle=(0, (1, 1)))
plt.plot(sample,fnt,'#009E73',label='False Negative Student-t',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
ax.legend(handles=[false_pos,false_neg,conf,trunc,student])
plt.xticks(sample)
plt.xlabel('Sample Size per Environment',fontsize=14)
plt.ylabel('Rate',fontsize=14)
plt.show()
plt.savefig('Figures/SamplechangNonNormalE='+str(I)+'.eps',bbox_inches="tight",format='eps')
# Out:
# Sample size 1 of 6
# Sample size 2 of 6
# Sample size 3 of 6
# Sample size 4 of 6
# Sample size 5 of 6
# Sample size 6 of 6
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:128: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:129: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:130: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:131: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.

# %%
### Changing noise strength
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
noise=[0,5,20,50,80]
fntrunc=np.zeros((len(noise)))
fptrunc=np.zeros((len(noise)))
fnt=np.zeros((len(noise)))
fpt=np.zeros((len(noise)))
fnind=np.zeros((len(noise)))
fpind=np.zeros((len(noise)))
fn=np.zeros((len(noise)))
fp=np.zeros((len(noise)))
runs=20
l=1 # Number of intervals we combine for the statistics
B=100 # Bootstrap runs
n=15
I=5      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,nos in enumerate(noise):
    print('Noise strength',o+1,'of',len(noise))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        Xtrunc=[]
        Ytrunc=[]
        Xt=[]
        Yt=[]
        for i in range(I):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=5,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),(2+nos)*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            ytrunc=np.zeros((n))
            yt=np.zeros((n))
            xtrunc=np.zeros((n,d))
            xt=np.zeros((n,d))
            
            mean=np.random.uniform(low=-1,high=1,size=(d))
            for p in range(d):
                temp=np.random.normal(mean[p],scale=std[p],size=(n))
                ind=np.where(temp>1.5+mean[p])
                temp[ind]=1.5+mean[p]
                ind=np.where(e<-1.5+mean[p])
                temp[ind]=-1.5+mean[p]
                xtrunc[:,p]=temp
                xt[:,p]=np.random.standard_t(2*(std[p])**(1/2)/((std[p])**(1/2)-1),size=(n))+mean[p]
                xind[:,p]=np.random.normal(mean[p],scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            etrunc=np.random.multivariate_normal(0*np.ones(n),(2+nos)*np.eye(n))
            ind=np.where(etrunc>2.5)
            etrunc[ind]=2.5
            ind=np.where(e<-2.5)
            etrunc[ind]=-2.5
            ytrunc=xtrunc@betas[r,i,:]+etrunc
            et=np.random.standard_t(2*((2+nos))**(1/2)/(((2+nos))**(1/2)-1),size=(n))
            yt=xt@betas[r,i,:]+et
            
            Xind.append(xind)
            Yind.append(yind)
            Xtrunc.append(xtrunc)
            Ytrunc.append(ytrunc)
            Xt.append(xt)
            Yt.append(yt)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs
                
                
        plausibleS=loli.gauss(Xtrunc,Ytrunc)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fptrunc[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fntrunc[o]+=1/runs
                
        plausibleS=loli.gauss(Xt,Yt)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpt[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnt[o]+=1/runs

fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
    
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
sem = Patch([], [], color='#785EF0',label='SEM')
normal = Patch([], [], color='#DC267F',label='Normal')
trunc = Patch([], [], color='#FE6100',label='Truncated normal')
student = Patch([], [], color='#009E73',label='Student-t')
conf= plt.Line2D([], [], color='black',label='Confidence level')

plt.plot(noise,0.1*np.ones((len(noise))),label='Confidence level',color='black')
plt.plot(noise,fp,'#785EF0',label='False Positive SEM',linestyle=(0, (5, 1)))
plt.plot(noise,fpind,'#DC267F',label='False Positive Normal',linestyle=(0, (5, 1)))
plt.plot(noise,fn,'#785EF0',label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(noise,fnind,'#DC267F',label='False Negative Normal',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
ax.legend(handles=[false_pos,false_neg,conf,sem,normal])
plt.xticks(noise+2)
plt.xlabel('Standard Deviation of Target Noise',fontsize=14)
plt.ylabel('Rate',fontsize=14)
plt.show()
plt.savefig('Figures/NoisechangeSem='+str(I)+'.eps',bbox_inches="tight",format='eps')


fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(noise,0.1*np.ones((len(noise))),label='Confidence level',color='black')
plt.plot(noise,fptrunc,'#FE6100',label='False Positive Truncated',linestyle=(0, (5, 1)))
plt.plot(noise,fpt,'#009E73',label='False Positive Student-t',linestyle=(0, (5, 1)))
plt.plot(noise,fntrunc,'#FE6100',label='False Negative Truncated',linestyle=(0, (1, 1)))
plt.plot(noise,fnt,'#009E73',label='False Negative Student-t',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
ax.legend(handles=[false_pos,false_neg,conf,trunc,student])
plt.xticks(noise)
plt.xlabel('Standard Deviation of Target Noise',fontsize=14)
plt.ylabel('Rate',fontsize=14)
plt.show()
plt.savefig('Figures/NoisechangeNonNormalE='+str(I)+'.eps',bbox_inches="tight",format='eps')
# Out:
# Noise strength 1 of 5
# Noise strength 2 of 5
# Noise strength 3 of 5
# Noise strength 4 of 5
# Noise strength 5 of 5
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:129: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:130: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:131: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# C:\ProgramData\Anaconda3\envs\causal\lib\site-packages\ipykernel_launcher.py:132: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26668\3050298042.py in <module>
#     141 false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
#     142 ax.legend(handles=[false_pos,false_neg,conf,sem,normal])
# --> 143 plt.xticks(noise+2)
#     144 plt.xlabel('Standard Deviation of Target Noise',fontsize=14)
#     145 plt.ylabel('Rate',fontsize=14)
#
# TypeError: can only concatenate list (not "int") to list

# %%
fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(signal,0.1*np.ones((len(signal))),label='Confidence level',color='black')
plt.plot(signal,fp,'#785EF0',label='False Positive SEM',linestyle=(0, (5, 1)))
plt.plot(signal,fpind,'#DC267F',label='False Positive Normal',linestyle=(0, (5, 1)))
plt.plot(signal,fptrunc,'#FE6100',label='False Positive Truncated',linestyle=(0, (5, 1)))
plt.plot(signal,fpt,'#009E73',label='False Positive Student-t',linestyle=(0, (5, 1)))
plt.plot(signal,fn,'#785EF0',label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(signal,fnind,'#DC267F',label='False Negative Normal',linestyle=(0, (1, 1)))
plt.plot(signal,fntrunc,'#FE6100',label='False Negative Truncated',linestyle=(0, (1, 1)))
plt.plot(signal,fnt,'#009E73',label='False Negative Student-t',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
sem = plt.Line2D([], [], color='#785EF0',label='SEM')
normal = plt.Line2D([], [], color='#DC267F',label='Normal')
trunc= plt.Line2D([], [], color='#FE6100',label='Truncated normal')
student = plt.Line2D([], [], color='#009E73',label='Student-t')
conf= plt.Line2D([], [], color='black',label='Confidence level')
ax.legend(handles=[false_pos,false_neg,sem,normal,trunc,student,conf])

plt.xlabel('Signal Strength',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.show()



fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(signal,0.1*np.ones((len(signal))),label='Confidence level',color='black')
plt.plot(signal,fp,'#785EF0',label='False Positive SEM',linestyle=(0, (5, 1)))
plt.plot(signal,fpind,'#DC267F',label='False Positive Normal',linestyle=(0, (5, 1)))
plt.plot(signal,fptrunc,'#FE6100',label='False Positive Truncated',linestyle=(0, (5, 1)))
plt.plot(signal,fpt,'#009E73',label='False Positive Student-t',linestyle=(0, (5, 1)))
plt.plot(signal,fn,'#785EF0',label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(signal,fnind,'#DC267F',label='False Negative Normal',linestyle=(0, (1, 1)))
plt.plot(signal,fntrunc,'#FE6100',label='False Negative Truncated',linestyle=(0, (1, 1)))
plt.plot(signal,fnt,'#009E73',label='False Negative Student-t',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
sem = plt.Line2D([], [], color='#785EF0',label='SEM')
normal = plt.Line2D([], [], color='#DC267F',label='Normal')
trunc= plt.Line2D([], [], color='#FE6100',label='Truncated normal')
student = plt.Line2D([], [], color='#009E73',label='Student-t')
conf= plt.Line2D([], [], color='black',label='Confidence level')
ax.legend(handles=[false_pos,false_neg,sem,normal,trunc,student,conf])

plt.xlabel('Signal Strength',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.show()

# %%
### Next, increasing noise strength
np.random.seed(0)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
noise=[1,10,20,40,60]
fn=np.zeros((len(noise)))
fp=np.zeros((len(noise)))
fnind=np.zeros((len(noise)))
fpind=np.zeros((len(noise)))
runs=100
n=15 # Sample size
I=50      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,nos in enumerate(noise):
    print('Noise strength',o+1,'of',len(noise))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        for i in range(I):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=5,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),nos*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            
            for p in range(d):
                xind[:,p]=np.random.normal(scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            Xind.append(xind)
            Yind.append(yind)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs


fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(noise,0.1*np.ones((len(noise))),label='Confidence level',color='black')
plt.plot(noise,fp,label='False Positive SEM',linestyle=(0, (1, 5)))
plt.plot(noise,fn,label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(noise,fpind,label='False Positive GAUSS',linestyle=(0, (5, 5)))
plt.plot(noise,fnind,label='False Negative GAUSS',linestyle=(0, (5, 1)))

plt.xlabel('Noise Strength',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.legend()
plt.savefig('Figures/Noisechangen='+str(n)+'.eps',bbox_inches="tight",format='eps')
# Out:
# Noise strength 1 of 5
# Noise strength 2 of 5
# Noise strength 3 of 5
# Noise strength 4 of 5
# Noise strength 5 of 5
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### Changing sample size
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
sample=[8,10,12,14,16,18,20]
fn=np.zeros((len(sample)))
fp=np.zeros((len(sample)))
fnind=np.zeros((len(sample)))
fpind=np.zeros((len(sample)))
runs=100
l=1 # Number of intervals we combine for the statistics
B=100 # Bootstrap runs
I=50      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,n in enumerate(sample):
    print('Sample size',o+1,'of',len(sample))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        for i in range(I):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=5,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),1*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            
            for p in range(d):
                xind[:,p]=np.random.normal(scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            Xind.append(xind)
            Yind.append(yind)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs

fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(sample,0.1*np.ones((len(sample))),label='Confidence level',color='black')
plt.plot(sample,fp,label='False Positive SEM',linestyle=(0, (1, 5)))
plt.plot(sample,fn,label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(sample,fpind,label='False Positive GAUSS',linestyle=(0, (5, 5)))
plt.plot(sample,fnind,label='False Negative GAUSS',linestyle=(0, (5, 1)))

plt.xlabel('Sample Size Per Environment',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.legend()
plt.savefig('Figures/Samplechangen.eps',bbox_inches="tight",format='eps')

# %%
### Changing number of environments
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
environments=[2,10,30,50,100,300]
fn=np.zeros((len(environments)))
fp=np.zeros((len(environments)))
fnind=np.zeros((len(environments)))
fpind=np.zeros((len(environments)))
runs=100
n=9 # Sample size
l=1 # Number of intervals we combine for the statistics
B=100 # Bootstrap runs
I=environments[-1]      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,es in enumerate(environments):
    print('Environments',o+1,'of',len(environments))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        for i in range(es):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=5,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),1*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            
            for p in range(d):
                xind[:,p]=np.random.normal(scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            Xind.append(xind)
            Yind.append(yind)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs

fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(environments,0.1*np.ones((len(environments))),label='Confidence level',color='black')
plt.plot(environments,fp,label='False Positive SEM',linestyle=(0, (1, 5)))
plt.plot(environments,fn,label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(environments,fpind,label='False Positive GAUSS',linestyle=(0, (5, 5)))
plt.plot(environments,fnind,label='False Negative GAUSS',linestyle=(0, (5, 1)))

plt.xlabel('Number of Environments',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.legend()
plt.savefig('Figures/Environmentchangen='+str(n)+'.eps',bbox_inches="tight",format='eps')
# Out:
# Environments 1 of 6
# Environments 2 of 6
# Environments 3 of 6
# Environments 4 of 6
# Environments 5 of 6
# Environments 6 of 6
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### Changing number of environments
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
environments=[2,10,30,50,100,300]
fn=np.zeros((len(environments)))
fp=np.zeros((len(environments)))
fnind=np.zeros((len(environments)))
fpind=np.zeros((len(environments)))
runs=100
n=8 # Sample size
l=1 # Number of intervals we combine for the statistics
B=100 # Bootstrap runs
I=environments[-1]      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,es in enumerate(environments):
    print('Environments',o+1,'of',len(environments))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        for i in range(es):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=5,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),1*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            
            for p in range(d):
                xind[:,p]=np.random.normal(scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            Xind.append(xind)
            Yind.append(yind)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs

fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(environments,0.1*np.ones((len(environments))),label='Confidence level',color='black')
plt.plot(environments,fp,label='False Positive SEM',linestyle=(0, (1, 5)))
plt.plot(environments,fn,label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(environments,fpind,label='False Positive GAUSS',linestyle=(0, (5, 5)))
plt.plot(environments,fnind,label='False Negative GAUSS',linestyle=(0, (5, 1)))

plt.xlabel('Number of Environments',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.legend()
plt.savefig('Figures/Environmentchangen='+str(n)+'.eps',bbox_inches="tight",format='eps')
# Out:
# Environments 1 of 6
# Environments 2 of 6
# Environments 3 of 6
# Environments 4 of 6
# Environments 5 of 6
# Environments 6 of 6
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### Changing heterogeinety strength
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
hetero=[0,1,2,4,6,8,10]
fn=np.zeros((len(hetero)))
fp=np.zeros((len(hetero)))
fnind=np.zeros((len(hetero)))
fpind=np.zeros((len(hetero)))
runs=100
n=15 # Sample size
l=1 # Number of intervals we combine for the statistics
B=100 # Bootstrap runs
I=50      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=1,size=(s))

for o,h in enumerate(hetero):
    print('Environment heterogeneity',o+1,'of',len(hetero))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        for i in range(I):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=1+h,size=(d))
            x[:,0]=np.random.normal(scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),1*np.eye(n))
            y=x@betas[r,i,:]+e
            x[:,4]=np.random.normal(scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            
            for p in range(d):
                xind[:,p]=np.random.normal(scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            Xind.append(xind)
            Yind.append(yind)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs

                
fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(hetero,0.1*np.ones((len(hetero))),label='Confidence level',color='black')
plt.plot(hetero,fp,label='False Positive SEM',linestyle=(0, (1, 5)))
plt.plot(hetero,fn,label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(hetero,fpind,label='False Positive GAUSS',linestyle=(0, (5, 5)))
plt.plot(hetero,fnind,label='False Negative GAUSS',linestyle=(0, (5, 1)))

plt.xlabel('Strength of Heterogeneity',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.legend()
plt.savefig('Figures/Heterochangen='+str(n)+'.eps',bbox_inches="tight",format='eps')
# Out:
# Environment heterogeneity 1 of 7
# Environment heterogeneity 2 of 7
# Environment heterogeneity 3 of 7
# Environment heterogeneity 4 of 7
# Environment heterogeneity 5 of 7
# Environment heterogeneity 6 of 7
# Environment heterogeneity 7 of 7
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### Next, increasing noise strength, with non-gaussian noise
np.random.seed(0)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
noise=[1,10,20,40,60]
fn=np.zeros((len(noise)))
fp=np.zeros((len(noise)))
fnind=np.zeros((len(noise)))
fpind=np.zeros((len(noise)))
runs=100
n=15 # Sample size
I=50      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,nos in enumerate(noise):
    print('Noise strength',o+1,'of',len(noise))
    for r in range(runs):
        Xgamma=[]
        Ygamma=[]
        Xuni=[]
        Yuni=[]
        for i in range(I):

            
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            
            for p in range(d):
                xind[:,p]=np.random.normal(scale=std[p],size=(n))
            yind=xind@betas[r,i,:]+e
            Xind.append(xind)
            Yind.append(yind)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs


fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(noise,0.1*np.ones((len(noise))),label='Confidence level',color='black')
plt.plot(noise,fp,label='False Positive SEM',linestyle=(0, (1, 5)))
plt.plot(noise,fn,label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(noise,fpind,label='False Positive GAUSS',linestyle=(0, (5, 5)))
plt.plot(noise,fnind,label='False Negative GAUSS',linestyle=(0, (5, 1)))

plt.xlabel('Noise Strength',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.legend()
plt.savefig('Figures/Noisechangen='+str(n)+'.eps',bbox_inches="tight",format='eps')

# %%
### First test, increasing signal strength
np.random.seed(1)
d=6  #Dimensionality
supp=(1,2) #support indices
s=len(supp)  #Number of support entries
signal=[0.01,0.05,0.1,0.5,1]
fn=np.zeros((len(signal)))
fp=np.zeros((len(signal)))
fntrunc=np.zeros((len(signal)))
fptrunc=np.zeros((len(signal)))
fnt=np.zeros((len(signal)))
fpt=np.zeros((len(signal)))
fnind=np.zeros((len(signal)))
fpind=np.zeros((len(signal)))
runs=20
n=15 # Sample size
I=5      #Number of Intervals 
a=[list(itertools.combinations(range(d), k)) for k in range(0,d+1)]
subsets = [item for sublist in a for item in sublist]
dic={}
# We first fix the data for all runs, to eliminate the randomness of this.
betas=np.zeros((runs,I,d))
for r in range(runs):
    for i in range(I):
        betas[r,i,supp]=np.random.uniform(low=1,high=5,size=(s))

for o,sig in enumerate(signal):
    print('Signal strength',o+1,'of',len(signal))
    for r in range(runs):
        X=[]
        Y=[]
        Xind=[]
        Yind=[]
        Xtrunc=[]
        Ytrunc=[]
        Xt=[]
        Yt=[]
        for i in range(I):
            x=np.zeros((n,d))
            y=np.zeros((n))
            std=np.random.uniform(low=1,high=10,size=(d))
            mean=np.random.uniform(low=-2,high=2,size=(d))
            x[:,0]=np.random.normal(mean[0],scale=std[0],size=(n))
            x[:,1]=x[:,0]+np.random.normal(mean[1],scale=std[1],size=(n))
            x[:,2]=0.3*x[:,1]+np.random.normal(mean[2],scale=std[2],size=(n))
            x[:,3]=0.2*x[:,2]+np.random.normal(mean[3],scale=std[3],size=(n))
            e=np.random.multivariate_normal(0*np.ones(n),1*np.eye(n))
            y=x@betas[r,i,:]*sig+e
            x[:,4]=np.random.normal(mean[4],scale=std[4],size=(n))+0.1*x[:,1]+y
            x[:,5]=np.random.normal(mean[5],scale=std[5],size=(n))+y

            X.append(x)
            Y.append(y)
            std=np.random.uniform(low=1,high=5,size=(d))
            xind=np.zeros((n,d))
            yind=np.zeros((n))
            ytrunc=np.zeros((n))
            yt=np.zeros((n))
            xtrunc=np.zeros((n,d))
            xt=np.zeros((n,d))


            for p in range(d):
                e=np.random.normal(mean[p],scale=std[p],size=(n))
                ind=np.where(e>1.5+mean[p])
                e[ind]=1.5
                ind=np.where(e<-1.5+mean[p])
                e[ind]=-1.5
                xtrunc[:,p]=e
                xt[:,p]=np.random.standard_t(2*(std[p])**(1/2)/((std[p])**(1/2)-1),size=(n))+mean[p]
                xind[:,p]=np.random.normal(mean[p],scale=std[p],size=(n))
            yind=xind@betas[r,i,:]*sig+e
            ytrunc=xind@betas[r,i,:]*sig+e
            yt=xind@betas[r,i,:]*sig+e
            
            Xind.append(xind)
            Yind.append(yind)
            Xtrunc.append(xtrunc)
            Ytrunc.append(ytrunc)
            Xt.append(xt)
            Yt.append(yt)
            
        plausibleS=loli.gauss(X,Y)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fp[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fn[o]+=1/runs
                
        plausibleS=loli.gauss(Xind,Yind)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpind[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnind[o]+=1/runs
                
        plausibleS=loli.gauss(Xtrunc,Ytrunc)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fptrunc[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fntrunc[o]+=1/runs
                
        plausibleS=loli.gauss(Xt,Yt)
        if not not plausibleS:
            supphat=set.intersection(*plausibleS)
            if len(supphat.difference(set(supp)))>0:
                fpt[o]+=1/runs
            if len(set(supp).difference(supphat))>0:
                fnt[o]+=1/runs


fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(signal,0.1*np.ones((len(signal))),label='Confidence level',color='black')
plt.plot(signal,fp,'#785EF0',label='False Positive SEM',linestyle=(0, (5, 1)))
plt.plot(signal,fpind,'#DC267F',label='False Positive Normal',linestyle=(0, (5, 1)))
plt.plot(signal,fn,'#785EF0',label='False Negative SEM',linestyle=(0, (1, 1)))
plt.plot(signal,fnind,'#DC267F',label='False Negative Normal',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
sem = plt.Line2D([], [], color='#785EF0',label='SEM')
normal = plt.Line2D([], [], color='#DC267F',label='Normal')
conf= plt.Line2D([], [], color='black',label='Confidence level')
ax.legend(handles=[false_pos,false_neg,sem,normal,conf])

plt.xlabel('Signal Strength',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.show()



fig, ax = plt.subplots()
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(14)
plt.plot(signal,0.1*np.ones((len(signal))),label='Confidence level',color='black')
plt.plot(signal,fptrunc,'#FE6100',label='False Positive Truncated',linestyle=(0, (5, 1)))
plt.plot(signal,fpt,'#009E73',label='False Positive Student-t',linestyle=(0, (5, 1)))
plt.plot(signal,fntrunc,'#FE6100',label='False Negative Truncated',linestyle=(0, (1, 1)))
plt.plot(signal,fnt,'#009E73',label='False Negative Student-t',linestyle=(0, (1, 1)))
false_pos = plt.Line2D([], [], color='black', linestyle=(0, (5, 1)),label='False positives')
false_neg = plt.Line2D([], [], color='black', linestyle=(0, (1, 1)),label='False negatives')
ax.legend(handles=[false_pos,false_neg,trunc,student,conf])

plt.xlabel('Signal Strength',fontsize=14)
plt.ylabel('FP/FN Rate',fontsize=14)
plt.show()
# plt.savefig('Figures/Signalchangen='+str(n)+'.eps',bbox_inches="tight",format='eps')
